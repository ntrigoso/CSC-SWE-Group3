# %% [markdown]
# # Print directory tree:

# %%
project_dir = "/Users/andrescortes/development/SWE/courier_tracking"

# %%
import os

def contains_target_files(directory, extensions):
    """
    Check if a directory contains files with the given extensions
    """
    for item in os.listdir(directory):
        if os.path.isdir(os.path.join(directory, item)):
            # Recursively check in subdirectories
            if contains_target_files(os.path.join(directory, item), extensions):
                return True
        elif any(item.endswith(ext) for ext in extensions):
            return True
    return False

def print_directory_hierarchy(path, indent=0, extensions=('.py', '.html')):
    # Check if the path is a directory
    if os.path.isdir(path):
        # Only proceed if the directory contains target files
        if contains_target_files(path, extensions):
            # Print the directory name with a trailing slash
            print('    ' * indent + os.path.basename(path) + '/')
            # Iterate over all items in the directory
            for item in os.listdir(path):
                # Recursively call this function for each item
                print_directory_hierarchy(os.path.join(path, item), indent + 1, extensions)
    else:
        # If it's a file, print its name only if it has the desired extension
        if path.endswith(extensions):
            print('    ' * indent + os.path.basename(path))

# Example usage

print_directory_hierarchy('/Users/andrescortes/development/SWE/courier_tracking')
# Out:
# courier_tracking/
#     business/
#         order/
#             models.py
#             __init__.py
#             apps.py
#             admin.py
#             tests.py
#             urls.py
#             views.py
#         migrations/
#             __init__.py
#         route/
#             models.py
#             __init__.py
#             apps.py
#             admin.py
#             tests.py
#             urls.py
#             views.py
#         models.py
#         driver/
#             models.py
#             __init__.py
#             apps.py
#             admin.py
#             tests.py
#             urls.py
#             views.py
#         __init__.py
#         apps.py
#         admin.py
#         inventory/
#             models.py
#             __init__.py
#             apps.py
#             admin.py
#             tests.py
#             urls.py
#             views.py
#         delivery/
#             models.py
#             __init__.py
#             apps.py
#             tests.py
#             urls.py
#             views.py
#         tests.py
#         urls.py
#         views.py
#     templates/
#         home.html
#         base.html
#         business/
#             business_portal.html
#             order/
#                 order_list.html
#             route/
#                 route_list.html
#             driver/
#                 driver_list.html
#             inventory/
#                 inventory_list.html
#             delivery/
#                 delivery_list.html
#         customer/
#             base.html
#     manage.py
#     courier_tracking/
#         asgi.py
#         __init__.py
#         settings.py
#         urls.py
#         wsgi.py
#     customer/
#         migrations/
#             __init__.py
#         models.py
#         __init__.py
#         apps.py
#         admin.py
#         tests.py
#         urls.py
#         views.py

# %% [markdown]
# # Print dependencies:

# %%
import os
import re
import pkg_resources

def generate_project_dependencies(project_dir):

    # Get installed packages
    installed_packages = {p.project_name: p.version for p in pkg_resources.working_set}
    
    # Scan project files for imports
    project_imports = set()
    for root, dirs, files in os.walk(project_dir):
        for file in files:
            if file.endswith('.py'):
                with open(os.path.join(root, file)) as f:
                    for line in f:
                        match = re.search(r'import (\w+)', line)
                        if match:
                            project_imports.add(match.group(1))
                            
    # Build dependency strings
    dependencies = []
    for pkg in project_imports:
        if pkg in installed_packages:
            version = installed_packages[pkg]
            dependencies.append(f"{pkg}=={version}")
        else:
            dependencies.append(pkg)
            
    return "\n".join(dependencies)
    
if __name__ == "__main__":
    print(generate_project_dependencies(project_dir))
# Out:
# uuid
# path
# json
# django
# DriverListView
# os
# render
# TestCase
# home
# AppConfig
# migrations
# Path
# Django==5.0.1
# Driver
# ListView
# models
# execute_from_command_line
# get_asgi_application
# get_wsgi_application
# admin
# sys

# %% [markdown]
# # With versions:

# %%
import os
import re
import pkg_resources
import sys

def generate_project_dependencies(project_dir):

    dependencies = {}

    # Get installed packages
    installed_pkgs = {p.project_name.lower(): p for p in pkg_resources.working_set}

    # Initialize categories
    categories = {
        "Built-in Modules": [],
        "Installed Packages": [],
        "Custom Modules": [],
        "Custom Classes": []
    }

    # Scan project files
    for root, dirs, files in os.walk(project_dir):
        for file in files:
            if file.endswith('.py'):
                with open(os.path.join(root, file)) as f:
                    for line in f: 
                        match = re.search(r'import (\w+)', line)
                        if match:
                            module = match.group(1)
                            if module in sys.builtin_module_names:
                                # Built-in, no version needed
                                categories["Built-in Modules"].append(module) 
                            elif module.lower() in installed_pkgs:
                                # Installed package
                                dep = installed_pkgs[module.lower()]
                                categories["Installed Packages"].append(f"{dep.project_name}=={dep.version}")
                            else:
                                # Custom module
                                categories["Custom Modules"].append(f"{os.path.join(root, file)} -> {module}")

        # Check for custom classes 
        for file in files:
            if file.endswith('.py'):
                with open(os.path.join(root, file)) as f:
                    for line in f:
                        match = re.search(r'class (\w+)\(', line)
                        if match:
                            categories["Custom Classes"].append(f"{os.path.join(root, file)} -> class {match.group(1)}()")

    return categories

if __name__ == "__main__":
    dependencies = generate_project_dependencies(project_dir)
    display(dependencies)
# Out:
# {'Built-in Modules': ['sys'],
#  'Installed Packages': ['Django==5.0.1',
#   'driver==0.1.0',
#   'Django==5.0.1',
#   'Django==5.0.1'],
#  'Custom Modules': ['/Users/mm/development/SWE/delivery/manage.py -> os',
#   '/Users/mm/development/SWE/delivery/manage.py -> execute_from_command_line',
#   '/Users/mm/development/SWE/delivery/driver_management/models.py -> models',
#   '/Users/mm/development/SWE/delivery/driver_management/apps.py -> AppConfig',
#   '/Users/mm/development/SWE/delivery/driver_management/admin.py -> admin',
#   '/Users/mm/development/SWE/delivery/driver_management/tests.py -> TestCase',
#   '/Users/mm/development/SWE/delivery/driver_management/urls.py -> path',
#   '/Users/mm/development/SWE/delivery/driver_management/urls.py -> DriverListView',
#   '/Users/mm/development/SWE/delivery/driver_management/views.py -> render',
#   '/Users/mm/development/SWE/delivery/driver_management/views.py -> ListView',
#   '/Users/mm/development/SWE/delivery/driver_management/migrations/0001_initial.py -> migrations',
#   '/Users/mm/development/SWE/delivery/order_management/models.py -> models',
#   '/Users/mm/development/SWE/delivery/order_management/models.py -> uuid',
#   '/Users/mm/development/SWE/delivery/order_management/apps.py -> AppConfig',
#   '/Users/mm/development/SWE/delivery/order_management/admin.py -> admin',
#   '/Users/mm/development/SWE/delivery/order_management/tests.py -> TestCase',
#   '/Users/mm/development/SWE/delivery/order_management/views.py -> render',
#   '/Users/mm/development/SWE/delivery/order_management/migrations/0001_initial.py -> uuid',
#   '/Users/mm/development/SWE/delivery/order_management/migrations/0001_initial.py -> migrations',
#   '/Users/mm/development/SWE/delivery/delivery_portal/asgi.py -> os',
#   '/Users/mm/development/SWE/delivery/delivery_portal/asgi.py -> get_asgi_application',
#   '/Users/mm/development/SWE/delivery/delivery_portal/settings.py -> Path',
#   '/Users/mm/development/SWE/delivery/delivery_portal/settings.py -> os',
#   '/Users/mm/development/SWE/delivery/delivery_portal/urls.py -> admin',
#   '/Users/mm/development/SWE/delivery/delivery_portal/urls.py -> path',
#   '/Users/mm/development/SWE/delivery/delivery_portal/urls.py -> home',
#   '/Users/mm/development/SWE/delivery/delivery_portal/views.py -> render',
#   '/Users/mm/development/SWE/delivery/delivery_portal/wsgi.py -> os',
#   '/Users/mm/development/SWE/delivery/delivery_portal/wsgi.py -> get_wsgi_application',
#   '/Users/mm/development/SWE/delivery/route_management/models.py -> uuid',
#   '/Users/mm/development/SWE/delivery/route_management/models.py -> json',
#   '/Users/mm/development/SWE/delivery/route_management/models.py -> models',
#   '/Users/mm/development/SWE/delivery/route_management/apps.py -> AppConfig',
#   '/Users/mm/development/SWE/delivery/route_management/admin.py -> admin',
#   '/Users/mm/development/SWE/delivery/route_management/tests.py -> TestCase',
#   '/Users/mm/development/SWE/delivery/route_management/views.py -> render',
#   '/Users/mm/development/SWE/delivery/route_management/migrations/0001_initial.py -> uuid',
#   '/Users/mm/development/SWE/delivery/route_management/migrations/0001_initial.py -> migrations'],
#  'Custom Classes': ['/Users/mm/development/SWE/delivery/driver_management/models.py -> class Driver()',
#   '/Users/mm/development/SWE/delivery/driver_management/models.py -> class Vehicle()',
#   '/Users/mm/development/SWE/delivery/driver_management/apps.py -> class DriverManagementConfig()',
#   '/Users/mm/development/SWE/delivery/driver_management/views.py -> class DriverListView()',
#   '/Users/mm/development/SWE/delivery/driver_management/migrations/0001_initial.py -> class Migration()',
#   '/Users/mm/development/SWE/delivery/order_management/models.py -> class Order()',
#   '/Users/mm/development/SWE/delivery/order_management/apps.py -> class OrderManagementConfig()',
#   '/Users/mm/development/SWE/delivery/order_management/migrations/0001_initial.py -> class Migration()',
#   '/Users/mm/development/SWE/delivery/route_management/models.py -> class Route()',
#   '/Users/mm/development/SWE/delivery/route_management/apps.py -> class RouteManagementConfig()',
#   '/Users/mm/development/SWE/delivery/route_management/migrations/0001_initial.py -> class Migration()']}

# %% [markdown]
# # UML Diagram:

# %%
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "delivery_portal.settings")

import django
django.setup()

from django_extensions.management.modelviz import GraphModels
import pygraphviz as pgv


def generate_uml_diagram():
    graph_models = GraphModels()
    dot_data = graph_models.get_graph_data(as_dot=True)
    
    graph = pgv.AGraph(dot_data)
    graph.layout() # neato layout
    graph.draw('django_uml.png')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 7
#       4 import django
#       5 django.setup()
# ----> 7 from django_extensions.management.modelviz import GraphModels
#       8 import pygraphviz as pgv
#      11 def generate_uml_diagram():
#
# ImportError: cannot import name 'GraphModels' from 'django_extensions.management.modelviz' (/Users/mm/clear/envs/FDS/lib/python3.11/site-packages/django_extensions/management/modelviz.py)

# %%
# !python manage.py graph_models -a -o my_project_model_diagram.png
# Out:
# Traceback (most recent call last):
#   File "/Users/mm/development/SWE/delivery/manage.py", line 22, in <module>
#     main()
#   File "/Users/mm/development/SWE/delivery/manage.py", line 18, in main
#     execute_from_command_line(sys.argv)
#   File "/Users/mm/clear/envs/FDS/lib/python3.11/site-packages/django/core/management/__init__.py", line 442, in execute_from_command_line
#     utility.execute()
#   File "/Users/mm/clear/envs/FDS/lib/python3.11/site-packages/django/core/management/__init__.py", line 436, in execute
#     self.fetch_command(subcommand).run_from_argv(self.argv)
#   File "/Users/mm/clear/envs/FDS/lib/python3.11/site-packages/django/core/management/base.py", line 412, in run_from_argv
#     self.execute(*args, **cmd_options)
#   File "/Users/mm/clear/envs/FDS/lib/python3.11/site-packages/django/core/management/base.py", line 458, in execute
#     output = self.handle(*args, **options)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mm/clear/envs/FDS/lib/python3.11/site-packages/django_extensions/management/utils.py", line 62, in inner
#     ret = func(self, *args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mm/clear/envs/FDS/lib/python3.11/site-packages/django_extensions/management/commands/graph_models.py", line 280, in handle
#     return self.render_output_pydot(dotdata, **options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mm/clear/envs/FDS/lib/python3.11/site-packages/django_extensions/management/commands/graph_models.py", line 345, in render_output_pydot
#     graph.write(output_file, format=format_)
#   File "/Users/mm/clear/envs/FDS/lib/python3.11/site-packages/pydotplus/graphviz.py", line 1918, in write
#     fobj.write(self.create(prog, format))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mm/clear/envs/FDS/lib/python3.11/site-packages/pydotplus/graphviz.py", line 1959, in create
#     raise InvocationException(
# pydotplus.graphviz.InvocationException: GraphViz's executables not found

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.1

# %% [markdown]
# # Contents of everything:

# %%
import os

# Define the relative path to the directory (change this as needed)
directory_path = "./"

# Define a list of target file names to match for Python files
target_python_files = [
    "models.py",
    "views.py",
    "urls.py",
    "settings.py",
    "manage.py",
    "apps.py",
    "admin.py",
    "0001_initial.py",  # You can add more Python files if needed
]

# Iterate through the directory and its subdirectories
for root, _, files in os.walk(directory_path):
    for file_name in files:
        file_path = os.path.join(root, file_name)
        if file_name.endswith('.html') or file_name in target_python_files:
            rel_path = os.path.relpath(file_path, directory_path)
            print(f"courier_tracking{rel_path}:")
            with open(file_path, "r") as file:
                print(file.read())
                print("\n" + "=" * 50 + "\n")  # Separating lines for readability
# Out:
# courier_trackingmanage.py:
#
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'courier_tracking.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
#             "available on your PYTHONPATH environment variable? Did you "
#             "forget to activate a virtual environment?"
#         ) from exc
#     execute_from_command_line(sys.argv)
#
#
# if __name__ == '__main__':
#     main()
#
#
# ==================================================
#
# courier_trackingbusiness/models.py:
# from django.db import models
#
#
#
#
# ==================================================
#
# courier_trackingbusiness/apps.py:
# from django.apps import AppConfig
#
#
# class BusinessConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business'
#
#
# ==================================================
#
# courier_trackingbusiness/admin.py:
# from django.contrib import admin
#
#
#
#
# ==================================================
#
# courier_trackingbusiness/urls.py:
# from django.urls import path, include
#
# urlpatterns = [
#   path('order/', include('business.order.urls')),
#   path('route/', include('business.route.urls')),
#   path('driver/', include('business.driver.urls')),
#   path('inventory/', include('business.inventory.urls')),
#   path('delivery/', include('business.delivery.urls')),
# ]
#
# ==================================================
#
# courier_trackingbusiness/views.py:
# from django.shortcuts import render
#
#
#
#
# ==================================================
#
# courier_trackingbusiness/order/models.py:
# from django.db import models
# import uuid
# from business.driver.models import Vehicle
#
#
# class Order(models.Model):
#     order_number = models.CharField(max_length=10, unique=True)
#     customer_name = models.CharField(max_length=60)
#     pickup_location = models.CharField(max_length=255)
#     drop_off_location = models.CharField(max_length=255)
#     departure_time = models.DateTimeField()
#     id = models.UUIDField(primary_key=True, default=uuid.uuid4, editable=False)
#     created_at = models.DateTimeField(auto_now_add=True)
#     updated_at = models.DateTimeField(auto_now=True)
#     vehicle = models.ForeignKey(Vehicle, on_delete=models.SET_NULL, blank=True, null=True)
#
#
#
#     STATUS_CHOICES = [
#         ('Processing', 'Processing'),
#         ('In Transit', 'In Transit'),
#         ('Delivered', 'Delivered')
#     ]
#     status = models.CharField(max_length=20, choices=STATUS_CHOICES, default='Processing')
#
#     def __str__(self):
#         return f"Order {self.order_number} is {self.status}. Pickup at {self.departure_time}"
#
#
# ==================================================
#
# courier_trackingbusiness/order/apps.py:
# from django.apps import AppConfig
#
# class OrderConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.order'
#
#
# ==================================================
#
# courier_trackingbusiness/order/admin.py:
# from django.contrib import admin
# from .models import Order
#
# class OrderAdmin(admin.ModelAdmin):
#     list_display = ['order_number', 'customer_name', 'status', 'vehicle_license']
#
#     def vehicle_license(self, obj):
#         return obj.vehicle.license_plate if obj.vehicle else 'No Vehicle'
#     vehicle_license.short_description = 'Vehicle License'
#
# admin.site.register(Order, OrderAdmin)
#
#
# ==================================================
#
# courier_trackingbusiness/order/urls.py:
# from django.urls import path
# from .views import OrderListView
#
# urlpatterns = [
#     path('', OrderListView.as_view(), name='order_list'),
# ]
#
# ==================================================
#
# courier_trackingbusiness/order/views.py:
#
#
# from django.views.generic import ListView
# from .models import Order
#
# class OrderListView(ListView):
#     model = Order
#     context_object_name = 'orders'
#     template_name = 'order/order_list.html'
#
#
# ==================================================
#
# courier_trackingbusiness/route/models.py:
# import uuid
# import json
# from django.db import models
#
# class Route(models.Model):
#     id = models.UUIDField(primary_key=True, default=uuid.uuid4, editable=False)
#     name = models.CharField(max_length=30)
#     origin = models.CharField(max_length=100)
#     destination = models.CharField(max_length=100, default='')
#     distance_miles = models.PositiveIntegerField()
#     stops = models.TextField()
#     arrival_times = models.TextField()
#     departure_times = models.TextField()
#
#     created_at = models.DateTimeField(auto_now_add=True)
#     updated_at = models.DateTimeField(auto_now=True)
#
#     def save(self, *args, **kwargs):
#
#         if isinstance(self.stops, list):
#             self.stops = json.dumps(self.stops)
#         if isinstance(self.arrival_times, list):
#             self.arrival_times = json.dumps(self.arrival_times)
#         if isinstance(self.departure_times, list):
#             self.departure_times = json.dumps(self.departure_times)
#         super().save(*args, **kwargs)
#
#     def __str__(self):
#         return f"{self.name} route"
#
#
# ==================================================
#
# courier_trackingbusiness/route/apps.py:
# from django.apps import AppConfig
#
# class RouteConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.route'
#
#
# ==================================================
#
# courier_trackingbusiness/route/admin.py:
# from django.contrib import admin
# from .models import Route
#
# class RouteAdmin(admin.ModelAdmin):
#   list_display = ['name', 'origin', 'destination']
#
# admin.site.register(Route, RouteAdmin)
#
# ==================================================
#
# courier_trackingbusiness/route/urls.py:
# from django.urls import path
# from .views import RouteListView
#
# urlpatterns = [
#     path('', RouteListView.as_view(), name='route_list'),
# ]
#
# ==================================================
#
# courier_trackingbusiness/route/views.py:
# from django.views.generic import ListView
# from .models import Route
#
# class RouteListView(ListView):
#     model = Route
#     context_object_name = 'routes'
#     template_name = 'route/route_list.html'
#
# ==================================================
#
# courier_trackingbusiness/driver/models.py:
# from django.db import models
#
# class Driver(models.Model):
#     first_name = models.CharField(max_length=50)
#     last_name = models.CharField(max_length=50)
#     employee_id = models.CharField(max_length=10, unique=True)
#     phone_number = models.CharField(max_length=20)
#     driver_license = models.CharField(max_length=50)
#     work_permit = models.ImageField(upload_to='work_permits/')
#     salary = models.DecimalField(max_digits=8, decimal_places=2)
#     schedule = models.TextField()
#
#     def __str__(self):
#         return f"{self.first_name} {self.last_name}"
#
# class Vehicle(models.Model):
#     license_plate = models.CharField(max_length=10, unique=True)
#     model = models.CharField(max_length=30)
#     driver = models.ForeignKey(Driver, on_delete=models.CASCADE)
#
#     def __str__(self):
#         return f"Vehicle {self.license_plate} - {self.model}"
#
#
# ==================================================
#
# courier_trackingbusiness/driver/apps.py:
# from django.apps import AppConfig
#
# class DriverConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.driver'
#
#
# ==================================================
#
# courier_trackingbusiness/driver/admin.py:
# from django.contrib import admin
# from .models import Driver, Vehicle
#
# class DriverAdmin(admin.ModelAdmin):
#   list_display = ['first_name', 'last_name', 'employee_id']
#
# class VehicleAdmin(admin.ModelAdmin):
#   list_display = ['license_plate', 'model']
#
# admin.site.register(Driver, DriverAdmin)
# admin.site.register(Vehicle, VehicleAdmin)
#
# ==================================================
#
# courier_trackingbusiness/driver/urls.py:
# from django.urls import path
# from .views import DeliveryListView
#
# urlpatterns = [
#     path('', DeliveryListView.as_view(), name='delivery_list'),
# ]
#
# ==================================================
#
# courier_trackingbusiness/driver/views.py:
#
#
# from django.views.generic import ListView
# from .models import Driver
#
# class DriverListView(ListView):
#     model = Driver
#     context_object_name = 'drivers'
#     template_name = 'driver/driver_list.html'
#
#
# ==================================================
#
# courier_trackingbusiness/inventory/models.py:
# from django.db import models
#
# class InventoryItem(models.Model):
#     name = models.CharField(max_length=50)
#     quantity = models.PositiveIntegerField()
#     cost = models.DecimalField(max_digits=6, decimal_places=2)
#     supplier = models.CharField(max_length=50)
#
#     def __str__(self):
#         return self.name
#
#
# ==================================================
#
# courier_trackingbusiness/inventory/apps.py:
# from django.apps import AppConfig
#
# class InventoryConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.inventory'
#
#
# ==================================================
#
# courier_trackingbusiness/inventory/admin.py:
# from django.contrib import admin
# from .models import InventoryItem
#
# class InventoryItemAdmin(admin.ModelAdmin):
#   list_display = ['name', 'quantity', 'supplier']
#
# admin.site.register(InventoryItem, InventoryItemAdmin)
#
# ==================================================
#
# courier_trackingbusiness/inventory/urls.py:
# from django.urls import path
# from .views import InventoryListView
#
# urlpatterns = [
#     path('', InventoryListView.as_view(), name='inventory_list'),
# ]
#
# ==================================================
#
# courier_trackingbusiness/inventory/views.py:
# from django.views.generic import ListView
# from .models import InventoryItem
#
# class InventoryListView(ListView):
#     model = InventoryItem
#     context_object_name = 'inventory_items'
#     template_name = 'inventory/inventory_list.html'
#
# ==================================================
#
# courier_trackingbusiness/delivery/models.py:
#
#
# ==================================================
#
# courier_trackingbusiness/delivery/apps.py:
# from django.apps import AppConfig
#
# class DeliveryConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.delivery'
#
#
# ==================================================
#
# courier_trackingbusiness/delivery/urls.py:
#
#
# from django.urls import path
# from .views import DeliveryListView
#
# urlpatterns = [
#     path('', DeliveryListView.as_view(), name='delivery_list'),
# ]
#
#
# ==================================================
#
# courier_trackingbusiness/delivery/views.py:
# from django.views.generic import ListView
# from .models import Delivery
#
# class DeliveryListView(ListView):
#     model = Delivery
#     context_object_name = 'deliveries'
#     template_name = 'delivery/delivery_list.html'
#
#
# ==================================================
#
# courier_trackingtemplates/home.html:
# <!-- delivery_portal/templates/home.html -->
#
# {% extends 'base.html' %}
# {% block content %}
# <div>
#     <h1>Welcome to my Delivery Portal!</h1>
#     <p>This is a simple and random paragraph of text.</p>
#     <div>
#         <a href="{% url 'customer_portal' %}"><button>Customer Login</button></a>
#         <a href="{% url 'business_portal' %}"><button>Business Login</button></a>
#     </div>
#     <ul>
#         <li>Item 1</li>
#         <li>Item 2</li>
#         <li>Item 3</li>
#     </ul>
# </div>
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingtemplates/base.html:
# <!-- delivery_portal/templates/base.html -->
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Delivery Portal</title>
#     <!-- Add any head content here -->
# </head>
# <body>
#     {% block content %}
#     {% endblock %}
# </body>
# </html>
#
#
# ==================================================
#
# courier_trackingtemplates/business/business_portal.html:
# {% extends 'base.html' %}
#
# {% block content %}
#
# <ul class="nav nav-tabs">
#   <li class="nav-item">
#     <a class="nav-link active" href="#drivers">Drivers</a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" href="#orders">Orders</a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" href="#routes">Routes</a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" href="#inventory">Inventory</a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" href="#deliveries">Deliveries</a>
#   </li>
# </ul>
#
# <div id="drivers">
#   {% include "business/driver/driver_list.html" %}
# </div>
#
# <div id="orders">
#   {% include "business/order/order_list.html" %}
# </div>
#
# <div id="routes">
#   {% include "business/route/route_list.html" %}
# </div>
#
# <div id="inventory">
#   {% include "business/inventory/inventory_list.html" %}
# </div>
#
# <div id="deliveries">
#   {% include "business/delivery/delivery_list.html" %}
# </div>
#
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingtemplates/business/order/order_list.html:
# {% extends "base.html" %}
#
# {% block content %}
#
# <h2>Orders</h2>
#
# <ul>
#   {% for order in orders %}
#     <li>Order Number: {{ order.order_number }} - Status: {{ order.status }}</li>
#   {% endfor %}
# </ul>
#
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingtemplates/business/route/route_list.html:
# {% extends "base.html" %}
#
# {% block content %}
#
# <h2>Routes</h2>
#
# <ul>
#   {% for route in routes %}
#     <li>Route Name: {{ route.name }} - Origin: {{ route.origin }} - Destination: {{ route.destination }}</li>
#   {% endfor %}
# </ul>
#
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingtemplates/business/driver/driver_list.html:
# {% extends "base.html" %}
#
# {% block content %}
#
# <h2>Drivers</h2>
#
# <ul>
#   {% for driver in drivers %}
#     <li>Name: {{ driver.first_name }} {{ driver.last_name }} - Employee ID: {{ driver.employee_id }}</li>
#   {% endfor %}
# </ul>
#
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingtemplates/business/inventory/inventory_list.html:
# {% extends "base.html" %}
#
# <h2>Inventory</h2>
#
# <ul>
#   {% for item in inventory %}
#     <li>{{ item.name }}</li>
#   {% endfor %}
# </ul>
#
#
# ==================================================
#
# courier_trackingtemplates/business/delivery/delivery_list.html:
# {% extends "base.html" %}
#
# {% block content %}
#
# <h2>Deliveries</h2>
#
# <ul>
#   {% for delivery in deliveries %}
#     <li>Tracking Number: {{ delivery.tracking_number }}</li>
#   {% endfor %}
# </ul>
#
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingtemplates/customer/base.html:
# {% extends 'base.html' %}
#
# {% block content %}
#   <h1>Manage Customers Here</h1>
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingcourier_tracking/settings.py:
# """
# Django settings for courier_tracking project.
#
# Generated by 'django-admin startproject' using Django 3.2.16.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/3.2/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/3.2/ref/settings/
# """
#
# from pathlib import Path
#
#
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
#
#
#
#
# SECRET_KEY = 'django-insecure-)w$onh
#
#
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
#
#
#
#
#
# INSTALLED_APPS = [
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
#     'customer.apps.CustomerConfig',
#     'business.apps.BusinessConfig',
#     'business.order.apps.OrderConfig',
#     'business.route.apps.RouteConfig',
#     'business.driver.apps.DriverConfig',
#     'business.inventory.apps.InventoryConfig',
#     'business.delivery.apps.DeliveryConfig',
# ]
#
#
#
#
# MIDDLEWARE = [
#     'django.middleware.security.SecurityMiddleware',
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.common.CommonMiddleware',
#     'django.middleware.csrf.CsrfViewMiddleware',
#     'django.contrib.auth.middleware.AuthenticationMiddleware',
#     'django.contrib.messages.middleware.MessageMiddleware',
#     'django.middleware.clickjacking.XFrameOptionsMiddleware',
# ]
#
# ROOT_URLCONF = 'courier_tracking.urls'
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         'DIRS': [os.path.join(BASE_DIR, 'templates')],
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#         },
#     },
# ]
#
# STATIC_URL = '/static/'
# STATIC_ROOT = os.path.join(BASE_DIR, 'static')
#
# MEDIA_URL = '/media/'
# MEDIA_ROOT = os.path.join(BASE_DIR, 'media')
#
#
# WSGI_APPLICATION = 'courier_tracking.wsgi.application'
#
#
#
#
#
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.sqlite3',
#         'NAME': BASE_DIR / 'db.sqlite3',
#     }
# }
#
#
#
#
#
# AUTH_PASSWORD_VALIDATORS = [
#     {
#         'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
#     },
# ]
#
#
#
#
#
# LANGUAGE_CODE = 'en-us'
#
# TIME_ZONE = 'UTC'
#
# USE_I18N = True
#
# USE_L10N = True
#
# USE_TZ = True
#
#
#
#
#
# STATIC_URL = '/static/'
#
#
#
#
# DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
#
#
# ==================================================
#
# courier_trackingcourier_tracking/urls.py:
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('customer/', include('customer.urls')),
#     path('business/', include('business.urls')),
# ]
#
#
# ==================================================
#
# courier_trackingcustomer/models.py:
# from django.db import models
#
# class Customer(models.Model):
#     name = models.CharField(max_length=50)
#     phone = models.CharField(max_length=10)
#
#     def __str__(self):
#         return self.name
#
#
# ==================================================
#
# courier_trackingcustomer/apps.py:
# from django.apps import AppConfig
#
#
# class CustomerConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'customer'
#
#
# ==================================================
#
# courier_trackingcustomer/admin.py:
# from django.contrib import admin
# from .models import Customer
#
# class CustomerAdmin(admin.ModelAdmin):
#   list_display = ['name', 'phone']
#
# admin.site.register(Customer, CustomerAdmin)
#
# ==================================================
#
# courier_trackingcustomer/urls.py:
# from django.urls import path
# from .views import CustomerListView
#
# urlpatterns = [
#     path('', CustomerListView.as_view(), name='customer_list'),
# ]
#
#
# ==================================================
#
# courier_trackingcustomer/views.py:
#
#
# from django.views.generic import ListView
# from .models import Customer
#
# class CustomerListView(ListView):
#     model = Customer
#     context_object_name = 'customers'
#     template_name = 'customer/customer_list.html'
#
#
# ==================================================

# %%
import os

# Define the path to the directory
directory_path = project_dir  # Replace 'project_dir' with the actual directory path

# Define a list of target file names to match
target_file_names = [
    "models.py",
    "views.py",
    "urls.py",
    "settings.py",
    "manage.py",
    "apps.py",
    "admin.py",
]

# Iterate through the directory and its subdirectories
for root, _, files in os.walk(directory_path):
    for file_name in files:
        if file_name.endswith('.html') or file_name in target_file_names:
            full_path = os.path.join(root, file_name)
            with open(full_path, "r") as file:
                print(f"Contents of {full_path}:")
                print(file.read())
                print("\n" + "=" * 50 + "\n")  # Separating lines for readability
# Out:
# Contents of /Users/andrescortes/development/SWE/courier_tracking/manage.py:
#
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'courier_tracking.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
#             "available on your PYTHONPATH environment variable? Did you "
#             "forget to activate a virtual environment?"
#         ) from exc
#     execute_from_command_line(sys.argv)
#
#
# if __name__ == '__main__':
#     main()
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/models.py:
# from django.db import models
#
#
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/apps.py:
# from django.apps import AppConfig
#
#
# class BusinessConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business'
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/admin.py:
# from django.contrib import admin
#
#
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/urls.py:
# from django.urls import path, include
#
# urlpatterns = [
#   path('order/', include('business.order.urls')),
#   path('route/', include('business.route.urls')),
#   path('driver/', include('business.driver.urls')),
#   path('inventory/', include('business.inventory.urls')),
#   path('delivery/', include('business.delivery.urls')),
# ]
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/views.py:
# from django.shortcuts import render
#
#
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/order/models.py:
# from django.db import models
# import uuid
# from business.driver.models import Vehicle
#
#
# class Order(models.Model):
#     order_number = models.CharField(max_length=10, unique=True)
#     customer_name = models.CharField(max_length=60)
#     pickup_location = models.CharField(max_length=255)
#     drop_off_location = models.CharField(max_length=255)
#     departure_time = models.DateTimeField()
#     id = models.UUIDField(primary_key=True, default=uuid.uuid4, editable=False)
#     created_at = models.DateTimeField(auto_now_add=True)
#     updated_at = models.DateTimeField(auto_now=True)
#     vehicle = models.ForeignKey(Vehicle, on_delete=models.SET_NULL, blank=True, null=True)
#
#
#
#     STATUS_CHOICES = [
#         ('Processing', 'Processing'),
#         ('In Transit', 'In Transit'),
#         ('Delivered', 'Delivered')
#     ]
#     status = models.CharField(max_length=20, choices=STATUS_CHOICES, default='Processing')
#
#     def __str__(self):
#         return f"Order {self.order_number} is {self.status}. Pickup at {self.departure_time}"
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/order/apps.py:
# from django.apps import AppConfig
#
# class OrderConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.order'
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/order/admin.py:
# from django.contrib import admin
# from .models import Order
#
# class OrderAdmin(admin.ModelAdmin):
#     list_display = ['order_number', 'customer_name', 'status', 'vehicle_license']
#
#     def vehicle_license(self, obj):
#         return obj.vehicle.license_plate if obj.vehicle else 'No Vehicle'
#     vehicle_license.short_description = 'Vehicle License'
#
# admin.site.register(Order, OrderAdmin)
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/order/urls.py:
# from django.urls import path
# from .views import OrderListView
#
# urlpatterns = [
#     path('', OrderListView.as_view(), name='order_list'),
# ]
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/order/views.py:
#
#
# from django.views.generic import ListView
# from .models import Order
#
# class OrderListView(ListView):
#     model = Order
#     context_object_name = 'orders'
#     template_name = 'order/order_list.html'
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/route/models.py:
# import uuid
# import json
# from django.db import models
#
# class Route(models.Model):
#     id = models.UUIDField(primary_key=True, default=uuid.uuid4, editable=False)
#     name = models.CharField(max_length=30)
#     origin = models.CharField(max_length=100)
#     destination = models.CharField(max_length=100, default='')
#     distance_miles = models.PositiveIntegerField()
#     stops = models.TextField()
#     arrival_times = models.TextField()
#     departure_times = models.TextField()
#
#     created_at = models.DateTimeField(auto_now_add=True)
#     updated_at = models.DateTimeField(auto_now=True)
#
#     def save(self, *args, **kwargs):
#
#         if isinstance(self.stops, list):
#             self.stops = json.dumps(self.stops)
#         if isinstance(self.arrival_times, list):
#             self.arrival_times = json.dumps(self.arrival_times)
#         if isinstance(self.departure_times, list):
#             self.departure_times = json.dumps(self.departure_times)
#         super().save(*args, **kwargs)
#
#     def __str__(self):
#         return f"{self.name} route"
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/route/apps.py:
# from django.apps import AppConfig
#
# class RouteConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.route'
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/route/admin.py:
# from django.contrib import admin
# from .models import Route
#
# class RouteAdmin(admin.ModelAdmin):
#   list_display = ['name', 'origin', 'destination']
#
# admin.site.register(Route, RouteAdmin)
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/route/urls.py:
# from django.urls import path
# from .views import RouteListView
#
# urlpatterns = [
#     path('', RouteListView.as_view(), name='route_list'),
# ]
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/route/views.py:
# from django.views.generic import ListView
# from .models import Route
#
# class RouteListView(ListView):
#     model = Route
#     context_object_name = 'routes'
#     template_name = 'route/route_list.html'
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/driver/models.py:
# from django.db import models
#
# class Driver(models.Model):
#     first_name = models.CharField(max_length=50)
#     last_name = models.CharField(max_length=50)
#     employee_id = models.CharField(max_length=10, unique=True)
#     phone_number = models.CharField(max_length=20)
#     driver_license = models.CharField(max_length=50)
#     work_permit = models.ImageField(upload_to='work_permits/')
#     salary = models.DecimalField(max_digits=8, decimal_places=2)
#     schedule = models.TextField()
#
#     def __str__(self):
#         return f"{self.first_name} {self.last_name}"
#
# class Vehicle(models.Model):
#     license_plate = models.CharField(max_length=10, unique=True)
#     model = models.CharField(max_length=30)
#     driver = models.ForeignKey(Driver, on_delete=models.CASCADE)
#
#     def __str__(self):
#         return f"Vehicle {self.license_plate} - {self.model}"
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/driver/apps.py:
# from django.apps import AppConfig
#
# class DriverConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.driver'
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/driver/admin.py:
# from django.contrib import admin
# from .models import Driver, Vehicle
#
# class DriverAdmin(admin.ModelAdmin):
#   list_display = ['first_name', 'last_name', 'employee_id']
#
# class VehicleAdmin(admin.ModelAdmin):
#   list_display = ['license_plate', 'model']
#
# admin.site.register(Driver, DriverAdmin)
# admin.site.register(Vehicle, VehicleAdmin)
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/driver/urls.py:
# from django.urls import path
# from .views import DeliveryListView
#
# urlpatterns = [
#     path('', DeliveryListView.as_view(), name='delivery_list'),
# ]
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/driver/views.py:
#
#
# from django.views.generic import ListView
# from .models import Driver
#
# class DriverListView(ListView):
#     model = Driver
#     context_object_name = 'drivers'
#     template_name = 'driver/driver_list.html'
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/inventory/models.py:
# from django.db import models
#
# class InventoryItem(models.Model):
#     name = models.CharField(max_length=50)
#     quantity = models.PositiveIntegerField()
#     cost = models.DecimalField(max_digits=6, decimal_places=2)
#     supplier = models.CharField(max_length=50)
#
#     def __str__(self):
#         return self.name
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/inventory/apps.py:
# from django.apps import AppConfig
#
# class InventoryConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.inventory'
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/inventory/admin.py:
# from django.contrib import admin
# from .models import InventoryItem
#
# class InventoryItemAdmin(admin.ModelAdmin):
#   list_display = ['name', 'quantity', 'supplier']
#
# admin.site.register(InventoryItem, InventoryItemAdmin)
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/inventory/urls.py:
# from django.urls import path
# from .views import InventoryListView
#
# urlpatterns = [
#     path('', InventoryListView.as_view(), name='inventory_list'),
# ]
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/inventory/views.py:
# from django.views.generic import ListView
# from .models import InventoryItem
#
# class InventoryListView(ListView):
#     model = InventoryItem
#     context_object_name = 'inventory_items'
#     template_name = 'inventory/inventory_list.html'
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/delivery/models.py:
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/delivery/apps.py:
# from django.apps import AppConfig
#
# class DeliveryConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.delivery'
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/delivery/urls.py:
#
#
# from django.urls import path
# from .views import DeliveryListView
#
# urlpatterns = [
#     path('', DeliveryListView.as_view(), name='delivery_list'),
# ]
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/business/delivery/views.py:
# from django.views.generic import ListView
# from .models import Delivery
#
# class DeliveryListView(ListView):
#     model = Delivery
#     context_object_name = 'deliveries'
#     template_name = 'delivery/delivery_list.html'
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/templates/home.html:
# <!-- delivery_portal/templates/home.html -->
#
# {% extends 'base.html' %}
# {% block content %}
# <div>
#     <h1>Welcome to my Delivery Portal!</h1>
#     <p>This is a simple and random paragraph of text.</p>
#     <div>
#         <a href="{% url 'customer_portal' %}"><button>Customer Login</button></a>
#         <a href="{% url 'business_portal' %}"><button>Business Login</button></a>
#     </div>
#     <ul>
#         <li>Item 1</li>
#         <li>Item 2</li>
#         <li>Item 3</li>
#     </ul>
# </div>
# {% endblock %}
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/templates/base.html:
# <!-- delivery_portal/templates/base.html -->
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Delivery Portal</title>
#     <!-- Add any head content here -->
# </head>
# <body>
#     {% block content %}
#     {% endblock %}
# </body>
# </html>
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/templates/business/business_portal.html:
# {% extends 'base.html' %}
#
# {% block content %}
#
# <ul class="nav nav-tabs">
#   <li class="nav-item">
#     <a class="nav-link active" href="#drivers">Drivers</a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" href="#orders">Orders</a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" href="#routes">Routes</a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" href="#inventory">Inventory</a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" href="#deliveries">Deliveries</a>
#   </li>
# </ul>
#
# <div id="drivers">
#   {% include "business/driver/driver_list.html" %}
# </div>
#
# <div id="orders">
#   {% include "business/order/order_list.html" %}
# </div>
#
# <div id="routes">
#   {% include "business/route/route_list.html" %}
# </div>
#
# <div id="inventory">
#   {% include "business/inventory/inventory_list.html" %}
# </div>
#
# <div id="deliveries">
#   {% include "business/delivery/delivery_list.html" %}
# </div>
#
# {% endblock %}
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/templates/business/order/order_list.html:
# {% extends "base.html" %}
#
# {% block content %}
#
# <h2>Orders</h2>
#
# <ul>
#   {% for order in orders %}
#     <li>Order Number: {{ order.order_number }} - Status: {{ order.status }}</li>
#   {% endfor %}
# </ul>
#
# {% endblock %}
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/templates/business/route/route_list.html:
# {% extends "base.html" %}
#
# {% block content %}
#
# <h2>Routes</h2>
#
# <ul>
#   {% for route in routes %}
#     <li>Route Name: {{ route.name }} - Origin: {{ route.origin }} - Destination: {{ route.destination }}</li>
#   {% endfor %}
# </ul>
#
# {% endblock %}
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/templates/business/driver/driver_list.html:
# {% extends "base.html" %}
#
# {% block content %}
#
# <h2>Drivers</h2>
#
# <ul>
#   {% for driver in drivers %}
#     <li>Name: {{ driver.first_name }} {{ driver.last_name }} - Employee ID: {{ driver.employee_id }}</li>
#   {% endfor %}
# </ul>
#
# {% endblock %}
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/templates/business/inventory/inventory_list.html:
# {% extends "base.html" %}
#
# <h2>Inventory</h2>
#
# <ul>
#   {% for item in inventory %}
#     <li>{{ item.name }}</li>
#   {% endfor %}
# </ul>
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/templates/business/delivery/delivery_list.html:
# {% extends "base.html" %}
#
# {% block content %}
#
# <h2>Deliveries</h2>
#
# <ul>
#   {% for delivery in deliveries %}
#     <li>Tracking Number: {{ delivery.tracking_number }}</li>
#   {% endfor %}
# </ul>
#
# {% endblock %}
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/templates/customer/base.html:
# {% extends 'base.html' %}
#
# {% block content %}
#   <h1>Manage Customers Here</h1>
# {% endblock %}
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/courier_tracking/settings.py:
# """
# Django settings for courier_tracking project.
#
# Generated by 'django-admin startproject' using Django 3.2.16.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/3.2/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/3.2/ref/settings/
# """
#
# from pathlib import Path
#
#
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
#
#
#
#
# SECRET_KEY = 'django-insecure-)w$onh
#
#
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
#
#
#
#
#
# INSTALLED_APPS = [
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
#     'customer.apps.CustomerConfig',
#     'business.apps.BusinessConfig',
#     'business.order.apps.OrderConfig',
#     'business.route.apps.RouteConfig',
#     'business.driver.apps.DriverConfig',
#     'business.inventory.apps.InventoryConfig',
#     'business.delivery.apps.DeliveryConfig',
# ]
#
#
#
#
# MIDDLEWARE = [
#     'django.middleware.security.SecurityMiddleware',
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.common.CommonMiddleware',
#     'django.middleware.csrf.CsrfViewMiddleware',
#     'django.contrib.auth.middleware.AuthenticationMiddleware',
#     'django.contrib.messages.middleware.MessageMiddleware',
#     'django.middleware.clickjacking.XFrameOptionsMiddleware',
# ]
#
# ROOT_URLCONF = 'courier_tracking.urls'
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         'DIRS': [os.path.join(BASE_DIR, 'templates')],
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#         },
#     },
# ]
#
# STATIC_URL = '/static/'
# STATIC_ROOT = os.path.join(BASE_DIR, 'static')
#
# MEDIA_URL = '/media/'
# MEDIA_ROOT = os.path.join(BASE_DIR, 'media')
#
#
# WSGI_APPLICATION = 'courier_tracking.wsgi.application'
#
#
#
#
#
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.sqlite3',
#         'NAME': BASE_DIR / 'db.sqlite3',
#     }
# }
#
#
#
#
#
# AUTH_PASSWORD_VALIDATORS = [
#     {
#         'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
#     },
# ]
#
#
#
#
#
# LANGUAGE_CODE = 'en-us'
#
# TIME_ZONE = 'UTC'
#
# USE_I18N = True
#
# USE_L10N = True
#
# USE_TZ = True
#
#
#
#
#
# STATIC_URL = '/static/'
#
#
#
#
# DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/courier_tracking/urls.py:
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('customer/', include('customer.urls')),
#     path('business/', include('business.urls')),
# ]
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/customer/models.py:
# from django.db import models
#
# class Customer(models.Model):
#     name = models.CharField(max_length=50)
#     phone = models.CharField(max_length=10)
#
#     def __str__(self):
#         return self.name
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/customer/apps.py:
# from django.apps import AppConfig
#
#
# class CustomerConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'customer'
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/customer/admin.py:
# from django.contrib import admin
# from .models import Customer
#
# class CustomerAdmin(admin.ModelAdmin):
#   list_display = ['name', 'phone']
#
# admin.site.register(Customer, CustomerAdmin)
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/customer/urls.py:
# from django.urls import path
# from .views import CustomerListView
#
# urlpatterns = [
#     path('', CustomerListView.as_view(), name='customer_list'),
# ]
#
#
# ==================================================
#
# Contents of /Users/andrescortes/development/SWE/courier_tracking/customer/views.py:
#
#
# from django.views.generic import ListView
# from .models import Customer
#
# class CustomerListView(ListView):
#     model = Customer
#     context_object_name = 'customers'
#     template_name = 'customer/customer_list.html'
#
#
# ==================================================

# %%
import os

# Define the root directory
root_directory = './'

# Function to find 'models.py' and 'admin.py' files and print their contents
def print_models_contents(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            if  file == 'settings.py' or file == 'apps.py' or file == 'models.py' or file == 'admin.py' or file == 'views.py' or file == 'urls.py':
                relative_path = os.path.relpath(root, directory)
                file_path = os.path.join(relative_path, file)  # Include the file name in the path
                with open(file_path, 'r') as f:
                    content = f.read()
                print(f'\n{file_path}:')  # Print the path to the file
                print(content)
                print( '='*30)

# Call the function with the root directory
print_models_contents(root_directory)
# Out:
# business/models.py:
# from django.db import models
#
#
#
# ==============================
#
# business/apps.py:
# from django.apps import AppConfig
#
#
# class BusinessConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business'
#
# ==============================
#
# business/admin.py:
# from django.contrib import admin
#
#
#
# ==============================
#
# business/urls.py:
# from django.urls import path, include
#
# urlpatterns = [
#   path('order/', include('business.order.urls')),
#   path('route/', include('business.route.urls')),
#   path('driver/', include('business.driver.urls')),
#   path('inventory/', include('business.inventory.urls')),
#   path('delivery/', include('business.delivery.urls')),
# ]
# ==============================
#
# business/views.py:
# from django.shortcuts import render
#
#
#
# ==============================
#
# business/order/models.py:
# from django.db import models
# import uuid
# from business.driver.models import Vehicle
#
#
# class Order(models.Model):
#     order_number = models.CharField(max_length=10, unique=True)
#     customer_name = models.CharField(max_length=60)
#     pickup_location = models.CharField(max_length=255)
#     drop_off_location = models.CharField(max_length=255)
#     departure_time = models.DateTimeField()
#     id = models.UUIDField(primary_key=True, default=uuid.uuid4, editable=False)
#     created_at = models.DateTimeField(auto_now_add=True)
#     updated_at = models.DateTimeField(auto_now=True)
#     vehicle = models.ForeignKey(Vehicle, on_delete=models.SET_NULL, blank=True, null=True)
#
#
#
#     STATUS_CHOICES = [
#         ('Processing', 'Processing'),
#         ('In Transit', 'In Transit'),
#         ('Delivered', 'Delivered')
#     ]
#     status = models.CharField(max_length=20, choices=STATUS_CHOICES, default='Processing')
#
#     def __str__(self):
#         return f"Order {self.order_number} is {self.status}. Pickup at {self.departure_time}"
#
# ==============================
#
# business/order/apps.py:
# from django.apps import AppConfig
#
# class OrderConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.order'
#
# ==============================
#
# business/order/admin.py:
# from django.contrib import admin
# from .models import Order
#
# class OrderAdmin(admin.ModelAdmin):
#     list_display = ['order_number', 'customer_name', 'status', 'vehicle_license']
#
#     def vehicle_license(self, obj):
#         return obj.vehicle.license_plate if obj.vehicle else 'No Vehicle'
#     vehicle_license.short_description = 'Vehicle License'
#
# admin.site.register(Order, OrderAdmin)
#
# ==============================
#
# business/order/urls.py:
# from django.urls import path
# from .views import OrderListView
#
# urlpatterns = [
#     path('', OrderListView.as_view(), name='order_list'),
# ]
# ==============================
#
# business/order/views.py:
#
#
# from django.views.generic import ListView
# from .models import Order
#
# class OrderListView(ListView):
#     model = Order
#     context_object_name = 'orders'
#     template_name = 'order/order_list.html'
#
# ==============================
#
# business/route/models.py:
# import uuid
# import json
# from django.db import models
#
# class Route(models.Model):
#     id = models.UUIDField(primary_key=True, default=uuid.uuid4, editable=False)
#     name = models.CharField(max_length=30)
#     origin = models.CharField(max_length=100)
#     destination = models.CharField(max_length=100, default='')
#     distance_miles = models.PositiveIntegerField()
#     stops = models.TextField()
#     arrival_times = models.TextField()
#     departure_times = models.TextField()
#
#     created_at = models.DateTimeField(auto_now_add=True)
#     updated_at = models.DateTimeField(auto_now=True)
#
#     def save(self, *args, **kwargs):
#
#         if isinstance(self.stops, list):
#             self.stops = json.dumps(self.stops)
#         if isinstance(self.arrival_times, list):
#             self.arrival_times = json.dumps(self.arrival_times)
#         if isinstance(self.departure_times, list):
#             self.departure_times = json.dumps(self.departure_times)
#         super().save(*args, **kwargs)
#
#     def __str__(self):
#         return f"{self.name} route"
#
# ==============================
#
# business/route/apps.py:
# from django.apps import AppConfig
#
# class RouteConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.route'
#
# ==============================
#
# business/route/admin.py:
# from django.contrib import admin
# from .models import Route
#
# class RouteAdmin(admin.ModelAdmin):
#   list_display = ['name', 'origin', 'destination']
#
# admin.site.register(Route, RouteAdmin)
# ==============================
#
# business/route/urls.py:
# from django.urls import path
# from .views import RouteListView
#
# urlpatterns = [
#     path('', RouteListView.as_view(), name='route_list'),
# ]
# ==============================
#
# business/route/views.py:
# from django.views.generic import ListView
# from .models import Route
#
# class RouteListView(ListView):
#     model = Route
#     context_object_name = 'routes'
#     template_name = 'route/route_list.html'
# ==============================
#
# business/driver/models.py:
# from django.db import models
#
# class Driver(models.Model):
#     first_name = models.CharField(max_length=50)
#     last_name = models.CharField(max_length=50)
#     employee_id = models.CharField(max_length=10, unique=True)
#     phone_number = models.CharField(max_length=20)
#     driver_license = models.CharField(max_length=50)
#     work_permit = models.ImageField(upload_to='work_permits/')
#     salary = models.DecimalField(max_digits=8, decimal_places=2)
#     schedule = models.TextField()
#
#     def __str__(self):
#         return f"{self.first_name} {self.last_name}"
#
# class Vehicle(models.Model):
#     license_plate = models.CharField(max_length=10, unique=True)
#     model = models.CharField(max_length=30)
#     driver = models.ForeignKey(Driver, on_delete=models.CASCADE)
#
#     def __str__(self):
#         return f"Vehicle {self.license_plate} - {self.model}"
#
# ==============================
#
# business/driver/apps.py:
# from django.apps import AppConfig
#
# class DriverConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.driver'
#
# ==============================
#
# business/driver/admin.py:
# from django.contrib import admin
# from .models import Driver, Vehicle
#
# class DriverAdmin(admin.ModelAdmin):
#   list_display = ['first_name', 'last_name', 'employee_id']
#
# class VehicleAdmin(admin.ModelAdmin):
#   list_display = ['license_plate', 'model']
#
# admin.site.register(Driver, DriverAdmin)
# admin.site.register(Vehicle, VehicleAdmin)
# ==============================
#
# business/driver/urls.py:
# from django.urls import path
# from .views import DeliveryListView
#
# urlpatterns = [
#     path('', DeliveryListView.as_view(), name='delivery_list'),
# ]
# ==============================
#
# business/driver/views.py:
#
#
# from django.views.generic import ListView
# from .models import Driver
#
# class DriverListView(ListView):
#     model = Driver
#     context_object_name = 'drivers'
#     template_name = 'driver/driver_list.html'
#
# ==============================
#
# business/inventory/models.py:
# from django.db import models
#
# class InventoryItem(models.Model):
#     name = models.CharField(max_length=50)
#     quantity = models.PositiveIntegerField()
#     cost = models.DecimalField(max_digits=6, decimal_places=2)
#     supplier = models.CharField(max_length=50)
#
#     def __str__(self):
#         return self.name
#
# ==============================
#
# business/inventory/apps.py:
# from django.apps import AppConfig
#
# class InventoryConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.inventory'
#
# ==============================
#
# business/inventory/admin.py:
# from django.contrib import admin
# from .models import InventoryItem
#
# class InventoryItemAdmin(admin.ModelAdmin):
#   list_display = ['name', 'quantity', 'supplier']
#
# admin.site.register(InventoryItem, InventoryItemAdmin)
# ==============================
#
# business/inventory/urls.py:
# from django.urls import path
# from .views import InventoryListView
#
# urlpatterns = [
#     path('', InventoryListView.as_view(), name='inventory_list'),
# ]
# ==============================
#
# business/inventory/views.py:
# from django.views.generic import ListView
# from .models import InventoryItem
#
# class InventoryListView(ListView):
#     model = InventoryItem
#     context_object_name = 'inventory_items'
#     template_name = 'inventory/inventory_list.html'
# ==============================
#
# business/delivery/models.py:
#
# ==============================
#
# business/delivery/apps.py:
# from django.apps import AppConfig
#
# class DeliveryConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.delivery'
#
# ==============================
#
# business/delivery/urls.py:
#
#
# from django.urls import path
# from .views import DeliveryListView
#
# urlpatterns = [
#     path('', DeliveryListView.as_view(), name='delivery_list'),
# ]
#
# ==============================
#
# business/delivery/views.py:
# from django.views.generic import ListView
# from .models import Delivery
#
# class DeliveryListView(ListView):
#     model = Delivery
#     context_object_name = 'deliveries'
#     template_name = 'delivery/delivery_list.html'
#
# ==============================
#
# courier_tracking/settings.py:
# """
# Django settings for courier_tracking project.
#
# Generated by 'django-admin startproject' using Django 3.2.16.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/3.2/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/3.2/ref/settings/
# """
#
# from pathlib import Path
#
#
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
#
#
#
#
# SECRET_KEY = 'django-insecure-)w$onh
#
#
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
#
#
#
#
#
# INSTALLED_APPS = [
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
#     'customer.apps.CustomerConfig',
#     'business.apps.BusinessConfig',
#     'business.order.apps.OrderConfig',
#     'business.route.apps.RouteConfig',
#     'business.driver.apps.DriverConfig',
#     'business.inventory.apps.InventoryConfig',
#     'business.delivery.apps.DeliveryConfig',
# ]
#
#
#
#
# MIDDLEWARE = [
#     'django.middleware.security.SecurityMiddleware',
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.common.CommonMiddleware',
#     'django.middleware.csrf.CsrfViewMiddleware',
#     'django.contrib.auth.middleware.AuthenticationMiddleware',
#     'django.contrib.messages.middleware.MessageMiddleware',
#     'django.middleware.clickjacking.XFrameOptionsMiddleware',
# ]
#
# ROOT_URLCONF = 'courier_tracking.urls'
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         'DIRS': [os.path.join(BASE_DIR, 'templates')],
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#         },
#     },
# ]
#
# STATIC_URL = '/static/'
# STATIC_ROOT = os.path.join(BASE_DIR, 'static')
#
# MEDIA_URL = '/media/'
# MEDIA_ROOT = os.path.join(BASE_DIR, 'media')
#
#
# WSGI_APPLICATION = 'courier_tracking.wsgi.application'
#
#
#
#
#
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.sqlite3',
#         'NAME': BASE_DIR / 'db.sqlite3',
#     }
# }
#
#
#
#
#
# AUTH_PASSWORD_VALIDATORS = [
#     {
#         'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
#     },
# ]
#
#
#
#
#
# LANGUAGE_CODE = 'en-us'
#
# TIME_ZONE = 'UTC'
#
# USE_I18N = True
#
# USE_L10N = True
#
# USE_TZ = True
#
#
#
#
#
# STATIC_URL = '/static/'
#
#
#
#
# DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
#
# ==============================
#
# courier_tracking/urls.py:
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('customer/', include('customer.urls')),
#     path('business/', include('business.urls')),
# ]
#
# ==============================
#
# customer/models.py:
# from django.db import models
#
# class Customer(models.Model):
#     name = models.CharField(max_length=50)
#     phone = models.CharField(max_length=10)
#
#     def __str__(self):
#         return self.name
#
# ==============================
#
# customer/apps.py:
# from django.apps import AppConfig
#
#
# class CustomerConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'customer'
#
# ==============================
#
# customer/admin.py:
# from django.contrib import admin
# from .models import Customer
#
# class CustomerAdmin(admin.ModelAdmin):
#   list_display = ['name', 'phone']
#
# admin.site.register(Customer, CustomerAdmin)
# ==============================
#
# customer/urls.py:
# from django.urls import path
# from .views import CustomerListView
#
# urlpatterns = [
#     path('', CustomerListView.as_view(), name='customer_list'),
# ]
#
# ==============================
#
# customer/views.py:
#
#
# from django.views.generic import ListView
# from .models import Customer
#
# class CustomerListView(ListView):
#     model = Customer
#     context_object_name = 'customers'
#     template_name = 'customer/customer_list.html'
#
# ==============================

# %%
import os

# Define the root directory
root_directory = '.'

# Function to find HTML files and print their contents
def print_html_contents(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.html'):
                relative_path = os.path.relpath(root, directory)
                file_path = os.path.join(root, file)  # Full file path including root
                if os.path.exists(file_path):
                    with open(file_path, 'r') as f:
                        content = f.read()
                    print(f'\n{file_path}:')  # Print the full file path
                    print(content)
                    print('='*30)
                else:
                    print(f"File not found: {file_path}")

# Call the function with the root directory
print_html_contents(root_directory)
# Out:
# ./templates/home.html:
# <!-- delivery_portal/templates/home.html -->
#
# {% extends 'base.html' %}
# {% block content %}
# <div>
#     <h1>Welcome to my Delivery Portal!</h1>
#     <p>This is a simple and random paragraph of text.</p>
#     <div>
#         <a href="{% url 'customer_portal' %}"><button>Customer Login</button></a>
#         <a href="{% url 'business_portal' %}"><button>Business Login</button></a>
#     </div>
#     <ul>
#         <li>Item 1</li>
#         <li>Item 2</li>
#         <li>Item 3</li>
#     </ul>
# </div>
# {% endblock %}
#
# ==============================
#
# ./templates/base.html:
# <!-- delivery_portal/templates/base.html -->
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Delivery Portal</title>
#     <!-- Add any head content here -->
# </head>
# <body>
#     {% block content %}
#     {% endblock %}
# </body>
# </html>
#
# ==============================
#
# ./templates/business/business_portal.html:
# {% extends 'base.html' %}
#
# {% block content %}
#
#   <ul class="nav nav-tabs">
#     <li class="nav-item">
#       <a class="nav-link active" href="#drivers">Drivers</a>
#     </li>
#     <li class="nav-item">
#       <a class="nav-link" href="#orders">Orders</a>
#     </li>
#     <li class="nav-item">
#       <a class="nav-link" href="#routes">Routes</a>
#     </li>
#   </ul>
#
#   <div id="drivers">
#     {% include "driver_management/driver_list.html" %}
#   </div>
#
#   <div id="orders">
#     {# Order management code here #}
#   </div>
#
#   <div id="routes">
#    {# Route management code here #}
#   </div>
#
# {% endblock %}
# ==============================
#
# ./templates/business/driver/driver_list.html:
# <h2>Drivers</h2>
#
# <ul>
#   <li>De</li>
#   <li>li</li>
#   <li>very</li>
# </ul>
#
# ==============================
#
# ./templates/business/inventory/inventory_list.html:
# {% extends "base.html" %}
#
# <h2>Inventory</h2>
#
# <ul>
#   {% for item in inventory %}
#     <li>{{ item.name }}</li>
#   {% endfor %}
# </ul>
#
# ==============================
#
# ./templates/customer/base.html:
# {% extends 'base.html' %}
#
# {% block content %}
#   <h1>Manage Customers Here</h1>
# {% endblock %}
# ==============================

# %%
import os

# Function to recursively print files with specified names and extensions
def print_files_in_directory(directory_path, target_names, extensions, indent_level=0):
    for root, _, files in os.walk(directory_path):
        for file_name in files:
            relative_path = os.path.relpath(os.path.join(root, file_name), directory_path)
            
            # Check if the file ends with one of the specified extensions
            if any(relative_path.endswith(ext) for ext in extensions):
                print("    " * indent_level + relative_path)
            
            # Check if the file name is in the target_names list
            if file_name in target_names:
                print("    " * indent_level + relative_path)
                
        for subdir in os.listdir(root):
            subdir_path = os.path.join(root, subdir)
            if os.path.isdir(subdir_path):
                print_files_in_directory(subdir_path, target_names, extensions, indent_level + 1)

# Current working directory
current_directory = os.getcwd()

# Target file names and extensions
target_file_names = [
    "models.py",
    "views.py",
    "urls.py",
    "settings.py",
    "manage.py",
    "apps.py",
    "admin.py",
]

extensions = ['.html']

print("Files:")
print_files_in_directory(current_directory, target_file_names, extensions)
# Out:
# Files:
# manage.py
#     models.py
#     apps.py
#     admin.py
#     urls.py
#     views.py
#         models.py
#         apps.py
#         admin.py
#         urls.py
#         views.py
#         models.py
#         apps.py
#         admin.py
#         urls.py
#         views.py
#         models.py
#         apps.py
#         admin.py
#         urls.py
#         views.py
#         models.py
#         apps.py
#         admin.py
#         urls.py
#         views.py
#         models.py
#         apps.py
#         urls.py
#         views.py
#     order/models.py
#     order/apps.py
#     order/admin.py
#     order/urls.py
#     order/views.py
#     route/models.py
#     route/apps.py
#     route/admin.py
#     route/urls.py
#     route/views.py
#     driver/models.py
#     driver/apps.py
#     driver/admin.py
#     driver/urls.py
#     driver/views.py
#     inventory/models.py
#     inventory/apps.py
#     inventory/admin.py
#     inventory/urls.py
#     inventory/views.py
#     delivery/models.py
#     delivery/apps.py
#     delivery/urls.py
#     delivery/views.py
#     home.html
#     base.html
#         business_portal.html
#             order_list.html
#             route_list.html
#             driver_list.html
#             inventory_list.html
#             delivery_list.html
#         order/order_list.html
#         route/route_list.html
#         driver/driver_list.html
#         inventory/inventory_list.html
#         delivery/delivery_list.html
#         base.html
#     business/business_portal.html
#         order_list.html
#         route_list.html
#         driver_list.html
#         inventory_list.html
#         delivery_list.html
#     business/order/order_list.html
#     business/route/route_list.html
#     business/driver/driver_list.html
#     business/inventory/inventory_list.html
#     business/delivery/delivery_list.html
#     customer/base.html
#     settings.py
#     urls.py
#     models.py
#     apps.py
#     admin.py
#     urls.py
#     views.py
# business/models.py
# business/apps.py
# business/admin.py
# business/urls.py
# business/views.py
#     models.py
#     apps.py
#     admin.py
#     urls.py
#     views.py
#     models.py
#     apps.py
#     admin.py
#     urls.py
#     views.py
#     models.py
#     apps.py
#     admin.py
#     urls.py
#     views.py
#     models.py
#     apps.py
#     admin.py
#     urls.py
#     views.py
#     models.py
#     apps.py
#     urls.py
#     views.py
# business/order/models.py
# business/order/apps.py
# business/order/admin.py
# business/order/urls.py
# business/order/views.py
# business/route/models.py
# business/route/apps.py
# business/route/admin.py
# business/route/urls.py
# business/route/views.py
# business/driver/models.py
# business/driver/apps.py
# business/driver/admin.py
# business/driver/urls.py
# business/driver/views.py
# business/inventory/models.py
# business/inventory/apps.py
# business/inventory/admin.py
# business/inventory/urls.py
# business/inventory/views.py
# business/delivery/models.py
# business/delivery/apps.py
# business/delivery/urls.py
# business/delivery/views.py
# templates/home.html
# templates/base.html
#     business_portal.html
#         order_list.html
#         route_list.html
#         driver_list.html
#         inventory_list.html
#         delivery_list.html
#     order/order_list.html
#     route/route_list.html
#     driver/driver_list.html
#     inventory/inventory_list.html
#     delivery/delivery_list.html
#     base.html
# templates/business/business_portal.html
#     order_list.html
#     route_list.html
#     driver_list.html
#     inventory_list.html
#     delivery_list.html
# templates/business/order/order_list.html
# templates/business/route/route_list.html
# templates/business/driver/driver_list.html
# templates/business/inventory/inventory_list.html
# templates/business/delivery/delivery_list.html
# templates/customer/base.html
# courier_tracking/settings.py
# courier_tracking/urls.py
# customer/models.py
# customer/apps.py
# customer/admin.py
# customer/urls.py
# customer/views.py

# %%
import os

# Define the relative path to the directory (change this as needed)
directory_path = "./"

# Define a list of target file names to match for Python files
target_python_files = [
    "models.py",
    "views.py",
    "urls.py",
    "settings.py",
    "manage.py",
    "apps.py",
    "admin.py",
    "0001_initial.py",  # You can add more Python files if needed
]

# Iterate through the directory and its subdirectories
for root, _, files in os.walk(directory_path):
    for file_name in files:
        file_path = os.path.join(root, file_name)
        if file_name.endswith('.html') or file_name in target_python_files:
            rel_path = os.path.relpath(file_path, directory_path)
            print(f"courier_tracking{rel_path}:")
            with open(file_path, "r") as file:
                print(file.read())
                print("\n" + "=" * 50 + "\n")  # Separating lines for readability
# Out:
# courier_trackingmanage.py:
#
# """Django's command-line utility for administrative tasks."""
# import os
# import sys
#
#
# def main():
#     """Run administrative tasks."""
#     os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'courier_tracking.settings')
#     try:
#         from django.core.management import execute_from_command_line
#     except ImportError as exc:
#         raise ImportError(
#             "Couldn't import Django. Are you sure it's installed and "
#             "available on your PYTHONPATH environment variable? Did you "
#             "forget to activate a virtual environment?"
#         ) from exc
#     execute_from_command_line(sys.argv)
#
#
# if __name__ == '__main__':
#     main()
#
#
# ==================================================
#
# courier_trackingbusiness/models.py:
# from django.db import models
#
#
#
#
# ==================================================
#
# courier_trackingbusiness/apps.py:
# from django.apps import AppConfig
#
#
# class BusinessConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business'
#
#
# ==================================================
#
# courier_trackingbusiness/admin.py:
# from django.contrib import admin
#
#
#
#
# ==================================================
#
# courier_trackingbusiness/urls.py:
# from django.urls import path, include
#
# urlpatterns = [
#   path('order/', include('business.order.urls')),
#   path('route/', include('business.route.urls')),
#   path('driver/', include('business.driver.urls')),
#   path('inventory/', include('business.inventory.urls')),
#   path('delivery/', include('business.delivery.urls')),
# ]
#
# ==================================================
#
# courier_trackingbusiness/views.py:
# from django.shortcuts import render
#
#
#
#
# ==================================================
#
# courier_trackingbusiness/order/models.py:
# from django.db import models
# import uuid
# from business.driver.models import Vehicle
#
#
# class Order(models.Model):
#     order_number = models.CharField(max_length=10, unique=True)
#     customer_name = models.CharField(max_length=60)
#     pickup_location = models.CharField(max_length=255)
#     drop_off_location = models.CharField(max_length=255)
#     departure_time = models.DateTimeField()
#     id = models.UUIDField(primary_key=True, default=uuid.uuid4, editable=False)
#     created_at = models.DateTimeField(auto_now_add=True)
#     updated_at = models.DateTimeField(auto_now=True)
#     vehicle = models.ForeignKey(Vehicle, on_delete=models.SET_NULL, blank=True, null=True)
#
#
#
#     STATUS_CHOICES = [
#         ('Processing', 'Processing'),
#         ('In Transit', 'In Transit'),
#         ('Delivered', 'Delivered')
#     ]
#     status = models.CharField(max_length=20, choices=STATUS_CHOICES, default='Processing')
#
#     def __str__(self):
#         return f"Order {self.order_number} is {self.status}. Pickup at {self.departure_time}"
#
#
# ==================================================
#
# courier_trackingbusiness/order/apps.py:
# from django.apps import AppConfig
#
# class OrderConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.order'
#
#
# ==================================================
#
# courier_trackingbusiness/order/admin.py:
# from django.contrib import admin
# from .models import Order
#
# class OrderAdmin(admin.ModelAdmin):
#     list_display = ['order_number', 'customer_name', 'status', 'vehicle_license']
#
#     def vehicle_license(self, obj):
#         return obj.vehicle.license_plate if obj.vehicle else 'No Vehicle'
#     vehicle_license.short_description = 'Vehicle License'
#
# admin.site.register(Order, OrderAdmin)
#
#
# ==================================================
#
# courier_trackingbusiness/order/urls.py:
# from django.urls import path
# from .views import OrderListView
#
# urlpatterns = [
#     path('', OrderListView.as_view(), name='order_list'),
# ]
#
# ==================================================
#
# courier_trackingbusiness/order/views.py:
#
#
# from django.views.generic import ListView
# from .models import Order
#
# class OrderListView(ListView):
#     model = Order
#     context_object_name = 'orders'
#     template_name = 'order/order_list.html'
#
#
# ==================================================
#
# courier_trackingbusiness/route/models.py:
# import uuid
# import json
# from django.db import models
#
# class Route(models.Model):
#     id = models.UUIDField(primary_key=True, default=uuid.uuid4, editable=False)
#     name = models.CharField(max_length=30)
#     origin = models.CharField(max_length=100)
#     destination = models.CharField(max_length=100, default='')
#     distance_miles = models.PositiveIntegerField()
#     stops = models.TextField()
#     arrival_times = models.TextField()
#     departure_times = models.TextField()
#
#     created_at = models.DateTimeField(auto_now_add=True)
#     updated_at = models.DateTimeField(auto_now=True)
#
#     def save(self, *args, **kwargs):
#
#         if isinstance(self.stops, list):
#             self.stops = json.dumps(self.stops)
#         if isinstance(self.arrival_times, list):
#             self.arrival_times = json.dumps(self.arrival_times)
#         if isinstance(self.departure_times, list):
#             self.departure_times = json.dumps(self.departure_times)
#         super().save(*args, **kwargs)
#
#     def __str__(self):
#         return f"{self.name} route"
#
#
# ==================================================
#
# courier_trackingbusiness/route/apps.py:
# from django.apps import AppConfig
#
# class RouteConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.route'
#
#
# ==================================================
#
# courier_trackingbusiness/route/admin.py:
# from django.contrib import admin
# from .models import Route
#
# class RouteAdmin(admin.ModelAdmin):
#   list_display = ['name', 'origin', 'destination']
#
# admin.site.register(Route, RouteAdmin)
#
# ==================================================
#
# courier_trackingbusiness/route/urls.py:
# from django.urls import path
# from .views import RouteListView
#
# urlpatterns = [
#     path('', RouteListView.as_view(), name='route_list'),
# ]
#
# ==================================================
#
# courier_trackingbusiness/route/views.py:
# from django.views.generic import ListView
# from .models import Route
#
# class RouteListView(ListView):
#     model = Route
#     context_object_name = 'routes'
#     template_name = 'route/route_list.html'
#
# ==================================================
#
# courier_trackingbusiness/driver/models.py:
# from django.db import models
#
# class Driver(models.Model):
#     first_name = models.CharField(max_length=50)
#     last_name = models.CharField(max_length=50)
#     employee_id = models.CharField(max_length=10, unique=True)
#     phone_number = models.CharField(max_length=20)
#     driver_license = models.CharField(max_length=50)
#     work_permit = models.ImageField(upload_to='work_permits/')
#     salary = models.DecimalField(max_digits=8, decimal_places=2)
#     schedule = models.TextField()
#
#     def __str__(self):
#         return f"{self.first_name} {self.last_name}"
#
# class Vehicle(models.Model):
#     license_plate = models.CharField(max_length=10, unique=True)
#     model = models.CharField(max_length=30)
#     driver = models.ForeignKey(Driver, on_delete=models.CASCADE)
#
#     def __str__(self):
#         return f"Vehicle {self.license_plate} - {self.model}"
#
#
# ==================================================
#
# courier_trackingbusiness/driver/apps.py:
# from django.apps import AppConfig
#
# class DriverConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.driver'
#
#
# ==================================================
#
# courier_trackingbusiness/driver/admin.py:
# from django.contrib import admin
# from .models import Driver, Vehicle
#
# class DriverAdmin(admin.ModelAdmin):
#   list_display = ['first_name', 'last_name', 'employee_id']
#
# class VehicleAdmin(admin.ModelAdmin):
#   list_display = ['license_plate', 'model']
#
# admin.site.register(Driver, DriverAdmin)
# admin.site.register(Vehicle, VehicleAdmin)
#
# ==================================================
#
# courier_trackingbusiness/driver/urls.py:
# from django.urls import path
# from .views import DeliveryListView
#
# urlpatterns = [
#     path('', DeliveryListView.as_view(), name='delivery_list'),
# ]
#
# ==================================================
#
# courier_trackingbusiness/driver/views.py:
#
#
# from django.views.generic import ListView
# from .models import Driver
#
# class DriverListView(ListView):
#     model = Driver
#     context_object_name = 'drivers'
#     template_name = 'driver/driver_list.html'
#
#
# ==================================================
#
# courier_trackingbusiness/inventory/models.py:
# from django.db import models
#
# class InventoryItem(models.Model):
#     name = models.CharField(max_length=50)
#     quantity = models.PositiveIntegerField()
#     cost = models.DecimalField(max_digits=6, decimal_places=2)
#     supplier = models.CharField(max_length=50)
#
#     def __str__(self):
#         return self.name
#
#
# ==================================================
#
# courier_trackingbusiness/inventory/apps.py:
# from django.apps import AppConfig
#
# class InventoryConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.inventory'
#
#
# ==================================================
#
# courier_trackingbusiness/inventory/admin.py:
# from django.contrib import admin
# from .models import InventoryItem
#
# class InventoryItemAdmin(admin.ModelAdmin):
#   list_display = ['name', 'quantity', 'supplier']
#
# admin.site.register(InventoryItem, InventoryItemAdmin)
#
# ==================================================
#
# courier_trackingbusiness/inventory/urls.py:
# from django.urls import path
# from .views import InventoryListView
#
# urlpatterns = [
#     path('', InventoryListView.as_view(), name='inventory_list'),
# ]
#
# ==================================================
#
# courier_trackingbusiness/inventory/views.py:
# from django.views.generic import ListView
# from .models import InventoryItem
#
# class InventoryListView(ListView):
#     model = InventoryItem
#     context_object_name = 'inventory_items'
#     template_name = 'inventory/inventory_list.html'
#
# ==================================================
#
# courier_trackingbusiness/delivery/models.py:
#
#
# ==================================================
#
# courier_trackingbusiness/delivery/apps.py:
# from django.apps import AppConfig
#
# class DeliveryConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'business.delivery'
#
#
# ==================================================
#
# courier_trackingbusiness/delivery/urls.py:
#
#
# from django.urls import path
# from .views import DeliveryListView
#
# urlpatterns = [
#     path('', DeliveryListView.as_view(), name='delivery_list'),
# ]
#
#
# ==================================================
#
# courier_trackingbusiness/delivery/views.py:
# from django.views.generic import ListView
# from .models import Delivery
#
# class DeliveryListView(ListView):
#     model = Delivery
#     context_object_name = 'deliveries'
#     template_name = 'delivery/delivery_list.html'
#
#
# ==================================================
#
# courier_trackingtemplates/home.html:
# <!-- delivery_portal/templates/home.html -->
#
# {% extends 'base.html' %}
# {% block content %}
# <div>
#     <h1>Welcome to my Delivery Portal!</h1>
#     <p>This is a simple and random paragraph of text.</p>
#     <div>
#         <a href="{% url 'customer_portal' %}"><button>Customer Login</button></a>
#         <a href="{% url 'business_portal' %}"><button>Business Login</button></a>
#     </div>
#     <ul>
#         <li>Item 1</li>
#         <li>Item 2</li>
#         <li>Item 3</li>
#     </ul>
# </div>
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingtemplates/base.html:
# <!-- delivery_portal/templates/base.html -->
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Delivery Portal</title>
#     <!-- Add any head content here -->
# </head>
# <body>
#     {% block content %}
#     {% endblock %}
# </body>
# </html>
#
#
# ==================================================
#
# courier_trackingtemplates/business/business_portal.html:
# {% extends 'base.html' %}
#
# {% block content %}
#
# <ul class="nav nav-tabs">
#   <li class="nav-item">
#     <a class="nav-link active" href="#drivers">Drivers</a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" href="#orders">Orders</a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" href="#routes">Routes</a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" href="#inventory">Inventory</a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" href="#deliveries">Deliveries</a>
#   </li>
# </ul>
#
# <div id="drivers">
#   {% include "business/driver/driver_list.html" %}
# </div>
#
# <div id="orders">
#   {% include "business/order/order_list.html" %}
# </div>
#
# <div id="routes">
#   {% include "business/route/route_list.html" %}
# </div>
#
# <div id="inventory">
#   {% include "business/inventory/inventory_list.html" %}
# </div>
#
# <div id="deliveries">
#   {% include "business/delivery/delivery_list.html" %}
# </div>
#
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingtemplates/business/order/order_list.html:
# {% extends "base.html" %}
#
# {% block content %}
#
# <h2>Orders</h2>
#
# <ul>
#   {% for order in orders %}
#     <li>Order Number: {{ order.order_number }} - Status: {{ order.status }}</li>
#   {% endfor %}
# </ul>
#
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingtemplates/business/route/route_list.html:
# {% extends "base.html" %}
#
# {% block content %}
#
# <h2>Routes</h2>
#
# <ul>
#   {% for route in routes %}
#     <li>Route Name: {{ route.name }} - Origin: {{ route.origin }} - Destination: {{ route.destination }}</li>
#   {% endfor %}
# </ul>
#
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingtemplates/business/driver/driver_list.html:
# {% extends "base.html" %}
#
# {% block content %}
#
# <h2>Drivers</h2>
#
# <ul>
#   {% for driver in drivers %}
#     <li>Name: {{ driver.first_name }} {{ driver.last_name }} - Employee ID: {{ driver.employee_id }}</li>
#   {% endfor %}
# </ul>
#
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingtemplates/business/inventory/inventory_list.html:
# {% extends "base.html" %}
#
# <h2>Inventory</h2>
#
# <ul>
#   {% for item in inventory %}
#     <li>{{ item.name }}</li>
#   {% endfor %}
# </ul>
#
#
# ==================================================
#
# courier_trackingtemplates/business/delivery/delivery_list.html:
# {% extends "base.html" %}
#
# {% block content %}
#
# <h2>Deliveries</h2>
#
# <ul>
#   {% for delivery in deliveries %}
#     <li>Tracking Number: {{ delivery.tracking_number }}</li>
#   {% endfor %}
# </ul>
#
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingtemplates/customer/base.html:
# {% extends 'base.html' %}
#
# {% block content %}
#   <h1>Manage Customers Here</h1>
# {% endblock %}
#
#
# ==================================================
#
# courier_trackingcourier_tracking/settings.py:
# """
# Django settings for courier_tracking project.
#
# Generated by 'django-admin startproject' using Django 3.2.16.
#
# For more information on this file, see
# https://docs.djangoproject.com/en/3.2/topics/settings/
#
# For the full list of settings and their values, see
# https://docs.djangoproject.com/en/3.2/ref/settings/
# """
#
# from pathlib import Path
#
#
# BASE_DIR = Path(__file__).resolve().parent.parent
#
#
#
#
#
#
# SECRET_KEY = 'django-insecure-)w$onh
#
#
# DEBUG = True
#
# ALLOWED_HOSTS = []
#
#
#
#
#
#
# INSTALLED_APPS = [
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
#     'customer.apps.CustomerConfig',
#     'business.apps.BusinessConfig',
#     'business.order.apps.OrderConfig',
#     'business.route.apps.RouteConfig',
#     'business.driver.apps.DriverConfig',
#     'business.inventory.apps.InventoryConfig',
#     'business.delivery.apps.DeliveryConfig',
# ]
#
#
#
#
# MIDDLEWARE = [
#     'django.middleware.security.SecurityMiddleware',
#     'django.contrib.sessions.middleware.SessionMiddleware',
#     'django.middleware.common.CommonMiddleware',
#     'django.middleware.csrf.CsrfViewMiddleware',
#     'django.contrib.auth.middleware.AuthenticationMiddleware',
#     'django.contrib.messages.middleware.MessageMiddleware',
#     'django.middleware.clickjacking.XFrameOptionsMiddleware',
# ]
#
# ROOT_URLCONF = 'courier_tracking.urls'
#
# TEMPLATES = [
#     {
#         'BACKEND': 'django.template.backends.django.DjangoTemplates',
#         'DIRS': [os.path.join(BASE_DIR, 'templates')],
#         'APP_DIRS': True,
#         'OPTIONS': {
#             'context_processors': [
#                 'django.template.context_processors.debug',
#                 'django.template.context_processors.request',
#                 'django.contrib.auth.context_processors.auth',
#                 'django.contrib.messages.context_processors.messages',
#             ],
#         },
#     },
# ]
#
# STATIC_URL = '/static/'
# STATIC_ROOT = os.path.join(BASE_DIR, 'static')
#
# MEDIA_URL = '/media/'
# MEDIA_ROOT = os.path.join(BASE_DIR, 'media')
#
#
# WSGI_APPLICATION = 'courier_tracking.wsgi.application'
#
#
#
#
#
# DATABASES = {
#     'default': {
#         'ENGINE': 'django.db.backends.sqlite3',
#         'NAME': BASE_DIR / 'db.sqlite3',
#     }
# }
#
#
#
#
#
# AUTH_PASSWORD_VALIDATORS = [
#     {
#         'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
#     },
#     {
#         'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
#     },
# ]
#
#
#
#
#
# LANGUAGE_CODE = 'en-us'
#
# TIME_ZONE = 'UTC'
#
# USE_I18N = True
#
# USE_L10N = True
#
# USE_TZ = True
#
#
#
#
#
# STATIC_URL = '/static/'
#
#
#
#
# DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
#
#
# ==================================================
#
# courier_trackingcourier_tracking/urls.py:
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('customer/', include('customer.urls')),
#     path('business/', include('business.urls')),
# ]
#
#
# ==================================================
#
# courier_trackingcustomer/models.py:
# from django.db import models
#
# class Customer(models.Model):
#     name = models.CharField(max_length=50)
#     phone = models.CharField(max_length=10)
#
#     def __str__(self):
#         return self.name
#
#
# ==================================================
#
# courier_trackingcustomer/apps.py:
# from django.apps import AppConfig
#
#
# class CustomerConfig(AppConfig):
#     default_auto_field = 'django.db.models.BigAutoField'
#     name = 'customer'
#
#
# ==================================================
#
# courier_trackingcustomer/admin.py:
# from django.contrib import admin
# from .models import Customer
#
# class CustomerAdmin(admin.ModelAdmin):
#   list_display = ['name', 'phone']
#
# admin.site.register(Customer, CustomerAdmin)
#
# ==================================================
#
# courier_trackingcustomer/urls.py:
# from django.urls import path
# from .views import CustomerListView
#
# urlpatterns = [
#     path('', CustomerListView.as_view(), name='customer_list'),
# ]
#
#
# ==================================================
#
# courier_trackingcustomer/views.py:
#
#
# from django.views.generic import ListView
# from .models import Customer
#
# class CustomerListView(ListView):
#     model = Customer
#     context_object_name = 'customers'
#     template_name = 'customer/customer_list.html'
#
#
# ==================================================
